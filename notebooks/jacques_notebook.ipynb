# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/jpelletier/code/DaveGiGi/Duckstradamus/notebooks

# %%
# !ls
# Out:
# jacques_data  jacques_notebook.ipynb

# %%
df = pd.read_csv("jacques_data/199708_Generation_MD.csv")

# %%
df.head()
# Out:
#   Site_Code POC_Code Nwk_Code       Gen_Code Fuel_Code Tech_Code Trading_date  \
# 0       ARA  ARA2201     MRPL      aratiatia     Hydro     Hydro   1997-08-01
# 1       ARG  ARG1101     TRUS  argyle_wairau     Hydro     Hydro   1997-08-01
# 2       ARI  ARI1101     MRPL        arapuni     Hydro     Hydro   1997-08-01
# 3       ATI  ATI2201     MRPL       atiamuri     Hydro     Hydro   1997-08-01
# 4       AVI  AVI2201     MERI       aviemore     Hydro     Hydro   1997-08-01
#
#      TP1    TP2    TP3  ...   TP41   TP42   TP43   TP44   TP45   TP46   TP47  \
# 0  29230  29100  29470  ...  33790  30310  27580  27110  27200  27310  27330
# 1      0      0      0  ...   3892    908      6      0      0      0      0
# 2  81510  81330  64800  ...  76160  72360  63180  62640  62310  63050  63130
# 3  19200  15270  15030  ...  29350  29650  29670  23190  19910  17830  17930
# 4  87970  87880  87770  ...  67190  53040  45970  47080  50350  50870  51740
#
#     TP48  TP49  TP50
# ...

# %%
df.shape
# Out:
# (1333, 57)

# %%
df.columns
# Out:
# Index(['Site_Code', 'POC_Code', 'Nwk_Code', 'Gen_Code', 'Fuel_Code',
#        'Tech_Code', 'Trading_date', 'TP1', 'TP2', 'TP3', 'TP4', 'TP5', 'TP6',
#        'TP7', 'TP8', 'TP9', 'TP10', 'TP11', 'TP12', 'TP13', 'TP14', 'TP15',
#        'TP16', 'TP17', 'TP18', 'TP19', 'TP20', 'TP21', 'TP22', 'TP23', 'TP24',
#        'TP25', 'TP26', 'TP27', 'TP28', 'TP29', 'TP30', 'TP31', 'TP32', 'TP33',
#        'TP34', 'TP35', 'TP36', 'TP37', 'TP38', 'TP39', 'TP40', 'TP41', 'TP42',
#        'TP43', 'TP44', 'TP45', 'TP46', 'TP47', 'TP48', 'TP49', 'TP50'],
#       dtype='object')

# %%
df["Site_Code"].unique()
# Out:
# array(['ARA', 'ARG', 'ARI', 'ATI', 'AVI', 'BEN', 'BWK', 'COB', 'COL',
#        'CYD', 'HLY', 'HWA', 'KIN', 'KPO', 'MAN', 'MAT', 'MHO', 'MTI',
#        'NPL', 'OHA', 'OHB', 'OHC', 'OHK', 'OKI', 'OTA', 'PPI', 'ROT',
#        'ROX', 'RPO', 'SFD', 'SWN', 'TKA', 'TKB', 'TKU', 'TMU', 'TUI',
#        'WHI', 'WKM', 'WPA', 'WRK', 'WTK'], dtype=object)

# %%
df["Fuel_Code"].unique()
# Out:
# array(['Hydro', 'Coal', 'Wood', 'Gas&Oil', 'Geo', 'Gas', 'Diesel'],
#       dtype=object)

# %%
df["Tech_Code"].unique()
# Out:
# array(['Hydro', 'Thrml', 'Cogen', 'Geo'], dtype=object)

# %%
df["Gen_Code"].nunique()
# Out:
# 41

# %%
df["Trading_date"].max()
# Out:
# '1997-08-31'
