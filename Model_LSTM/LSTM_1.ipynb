# %% [markdown]
# # LSTM Model Version 1 Testing

# %% [markdown]
# ## Goal & Setup
#
# - **Task:** given the past week of weather, predict the next 24 hours
# - **Target:** start with a **single variable** (e.g. `temperature`) — predicting multiple targets is a later extension (noted in Phase 3)
# - **Data:** 4-year subset of hourly weather (~35,000 rows) to keep experiments fast
# - **Approach:** direct multi-step forecast — the model outputs all 24 future values at once via a `Dense(24)` head

# %%
# Data Import
import sys
sys.path.append('../notebooks/Jacques')
from full_cleaning_preprocessing_script import run_full_preprocessing

# General
import pandas as pd
import numpy as np
import os
from typing import List
import matplotlib.pyplot as plt

# Metrics Evaluation
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Deep Learning Architecture
from keras import models, Input, layers, optimizers, regularizers
from keras.layers import Normalization
from keras.optimizers.schedules import ExponentialDecay
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## Phase 0 — Inputs (what the model expects)

# %%
df = run_full_preprocessing(
    data_folder = "/home/jpelletier/Downloads/data",
    start_date = "2019-01-01",
    end_date = "2024-12-31",
    save_path = "/home/jpelletier/Downloads/data/preprocessed_data.csv"
)
# Out:
# ============================================================
# DUCKSTRADAMUS — FULL PREPROCESSING PIPELINE
#   data_folder : /home/jpelletier/Downloads/data
#   date range  : 2019-01-01  →  2024-12-31
#   save_path   : /home/jpelletier/Downloads/data/preprocessed_data.csv
# ============================================================
#
# [1/9] Wholesale price...
#       Anchor df shape: (52585, 10)
#
# [2/9] Generation output...
#       Shape after merge: (52585, 19)
#
# [3/9] Wind...
#       Shape after merge: (52585, 29)
#
# [4/9] Solar...
#       Shape after merge: (52585, 41)
#
# [5/9] Temperature...
#       Shape after merge: (52585, 47)
#
# [6/9] Lake storage...
#       Merged: NI_TPO_Storage_LakeTaupo.csv  (prefix: 'NI_TPO_')
#       Merged: NI_WKA_Storage_LakeWaikaremoana.csv  (prefix: 'NI_WKA_')
#       Merged: SI_HWE_Storage_LakeHawea.csv  (prefix: 'SI_HWE_')
#       Merged: SI_MAN_Storage_LakeManapouri.csv  (prefix: 'SI_MAN_')
#       Merged: SI_OHA_Storage_LakeOhau.csv  (prefix: 'SI_OHA_')
#       Merged: SI_PKI_Storage_LakePukaki.csv  (prefix: 'SI_PKI_')
#       Merged: SI_TAU_Storage_LakeTeAnau.csv  (prefix: 'SI_TAU_')
#       Merged: SI_TKA_Storage_LakeTekapo.csv  (prefix: 'SI_TKA_')
#       Merged: SI_WAN_Storage_LakeWanaka.csv  (prefix: 'SI_WAN_')
#       Merged: SI_WPU_Storage_LakeWakatipu.csv  (prefix: 'SI_WPU_')
#       Shape after all lake merges: (52585, 67)
#
# [7/9] Holidays...
#       Shape after merge: (52585, 68)
#
# [8/9] Demand per zone...
#       Shape after merge: (52585, 73)
#
# [9/9] HVDC and scheduled outages...
#       Shape after merge: (52585, 81)
#    Saved to    : /home/jpelletier/Downloads/data/preprocessed_data.csv
#
# ============================================================
# ✅ Pipeline complete.
#    Final shape : (52585, 81)
#    Saved to    : /home/jpelletier/Downloads/data/preprocessed_data.csv
# ============================================================

# %%
df = df.set_index('datetime_utc12').sort_index()

# %%
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (52585, 80)
# ['el_price_dol_MWh_BEN2201', 'el_price_dol_MWh_HAY2201', 'el_price_dol_MWh_INV2201', 'el_price_dol_MWh_ISL2201', 'el_price_dol_MWh_KIK2201', 'el_price_dol_MWh_OTA2201', 'el_price_dol_MWh_RDF2201', 'el_price_dol_MWh_SFD2201', 'el_price_dol_MWh_WKM2201', 'Coal', 'Diesel', 'Ele', 'Gas', 'Geo', 'Hydro', 'Solar', 'Wind', 'Wood', 'palmerston_north_wind_kmh', 'palmerston_north_wind_dir_deg', 'wellington_wind_kmh', 'wellington_wind_dir_deg', 'harapaki_hawkesbay_wind_kmh', 'harapaki_hawkesbay_wind_dir_deg', 'te_uku_waikato_wind_kmh', 'te_uku_waikato_wind_dir_deg', 'kaiwera_downs_southland_wind_kmh', 'kaiwera_downs_southland_wind_dir_deg', 'auckland_shortwave_wm2', 'auckland_sunshine_s', 'christchurch_shortwave_wm2', 'christchurch_sunshine_s', 'wellington_shortwave_wm2', 'wellington_sunshine_s', 'hamilton_shortwave_wm2', 'hamilton_sunshine_s', 'tauranga_shortwave_wm2', 'tauranga_sunshine_s', 'dunedin_shortwave_wm2', 'dunedin_sunshine_s', 'auckland_temp_c', 'christchurch_temp_c', 'wellington_temp_c', 'hamilton_temp_c', 'tauranga_temp_c', 'dunedin_temp_c', 'NI_TPO__lake_level_m', 'NI_TPO__active_storage_mm³', 'NI_WKA__lake_level_m', 'NI_WKA__active_storage_mm³', 'SI_HWE__lake_level_m', 'SI_HWE__active_storage_mm³', 'SI_MAN__lake_level_m', 'SI_MAN__active_storage_mm³', 'SI_OHA__lake_level_m', 'SI_OHA__active_storage_mm³', 'SI_PKI__lake_level_m', 'SI_PKI__active_storage_mm³', 'SI_TAU__lake_level_m', 'SI_TAU__active_storage_mm³', 'SI_TKA__lake_level_m', 'SI_TKA__active_storage_mm³', 'SI_WAN__lake_level_m', 'SI_WAN__active_storage_mm³', 'SI_WPU__lake_level_m', 'SI_WPU__active_storage_mm³', 'holiday', 'demand_GWh_CNI', 'demand_GWh_LNI', 'demand_GWh_LSI', 'demand_GWh_UNI', 'demand_GWh_USI', 'avg_flow_MW', 'peak_flow_MW', 'Direction', 'outage_Gas_MW', 'outage_Hyd_MW', 'outage_Ter_MW', 'outage_Win_MW', 'outage_UNKN_MW']
#                      el_price_dol_MWh_BEN2201  el_price_dol_MWh_HAY2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   169.985                    171.76
# 2019-01-01 01:00:00                   156.335                    157.87
# 2019-01-01 02:00:00                   139.650                    141.00
# 2019-01-01 03:00:00                   128.845                    129.98
# 2019-01-01 04:00:00                   134.865                    136.14
#
#                      el_price_dol_MWh_INV2201  el_price_dol_MWh_ISL2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   180.715                   181.835
# 2019-01-01 01:00:00                   166.360                   167.215
# 2019-01-01 02:00:00                   148.550                   149.095
# 2019-01-01 03:00:00                   137.375                   137.215
# 2019-01-01 04:00:00                   144.585                   143.745
#
#                      el_price_dol_MWh_KIK2201  el_price_dol_MWh_OTA2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   184.255                   176.515
# 2019-01-01 01:00:00                   169.400                   162.070
# 2019-01-01 02:00:00                   151.050                   144.645
# 2019-01-01 03:00:00                   139.015                   133.355
# 2019-01-01 04:00:00                   145.670                   139.955
#
#                      el_price_dol_MWh_RDF2201  el_price_dol_MWh_SFD2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   166.425                   169.515
# 2019-01-01 01:00:00                   152.940                   155.645
# 2019-01-01 02:00:00                   136.500                   138.990
# 2019-01-01 03:00:00                   125.830                   128.130
# 2019-01-01 04:00:00                   132.130                   134.465
#
#                      el_price_dol_MWh_WKM2201  Coal  ...  demand_GWh_UNI  \
# datetime_utc12                                       ...
# 2019-01-01 00:00:00                   167.185   0.0  ...           0.910
# 2019-01-01 01:00:00                   153.635   0.0  ...           0.889
# 2019-01-01 02:00:00                   137.120   0.0  ...           0.853
# 2019-01-01 03:00:00                   126.400   0.0  ...           0.833
# 2019-01-01 04:00:00                   132.725   0.0  ...           0.835
#
#                      demand_GWh_USI  avg_flow_MW  peak_flow_MW  Direction  \
# datetime_utc12
# 2019-01-01 00:00:00           0.528        137.5         148.0        1.0
# 2019-01-01 01:00:00           0.483        129.5         133.0        1.0
# 2019-01-01 02:00:00           0.457        126.0         128.0        1.0
# 2019-01-01 03:00:00           0.446        126.5         132.0        1.0
# 2019-01-01 04:00:00           0.460        146.0         155.0        1.0
#
#                      outage_Gas_MW  outage_Hyd_MW  outage_Ter_MW  \
# datetime_utc12
# 2019-01-01 00:00:00           40.0           84.0          590.0
# 2019-01-01 01:00:00           40.0           84.0          590.0
# 2019-01-01 02:00:00           40.0           84.0          590.0
# 2019-01-01 03:00:00           40.0           84.0          590.0
# 2019-01-01 04:00:00           40.0           84.0          590.0
#
#                      outage_Win_MW  outage_UNKN_MW
# datetime_utc12
# 2019-01-01 00:00:00           48.3            14.0
# 2019-01-01 01:00:00           48.3            14.0
# 2019-01-01 02:00:00           48.3            14.0
# 2019-01-01 03:00:00           48.3            14.0
# 2019-01-01 04:00:00           48.3            14.0
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Create Naive Baseline

# %%
df['naive_baseline'] = df['el_price_dol_MWh_OTA2201'].shift(1)

# %%
# Drop the first row since shift(1) gives NaN there
mask = df['naive_baseline'].notna()

mae  = mean_absolute_error(df.loc[mask, 'el_price_dol_MWh_OTA2201'], df.loc[mask, 'naive_baseline'])
rmse = np.sqrt(mean_squared_error(df.loc[mask, 'el_price_dol_MWh_OTA2201'], df.loc[mask, 'naive_baseline']))

print(f'MAE  : {mae:.4f}')
print(f'RMSE : {rmse:.4f}')
# Out:
# MAE  : 23.6814
# RMSE : 72.6089

# %% [markdown]
# ## Phase 1 — Lastmile Preprocessing

# %% [markdown]
# ### Observations
#
# Some columns with 18 and 6 missing values. Will simply impute and fill given extremely low percentage of these values (0.03% and 0.01%, respectivelly.
#
# Check with:
# - df.isnull().sum()
# - df.isnull().sum() / len(df) * 100

# %%
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_rows')

# %%
# 1. Ensure chronological order, no gaps
df = df.sort_index()

# %%
# 2. Handle missing values (weather sensors have gaps)
#    Forward-fill carries the last reading; back-fill covers any leading NaNs
df = df.ffill().bfill()

# %%
# 3. Add cyclical time features — helps the model learn daily & yearly rhythm
#    (Same sin/cos trick as the generation-data cyclic encoding)
hour = df.index.hour
doy  = df.index.dayofyear
df['hour_sin'] = np.sin(2 * np.pi * hour / 24)
df['hour_cos'] = np.cos(2 * np.pi * hour / 24)
df['doy_sin']  = np.sin(2 * np.pi * doy / 365)
df['doy_cos']  = np.cos(2 * np.pi * doy / 365)

# %%
# 4. (Optional) keep only the features you want the model to see
#    Fewer, relevant features = faster training and less overfitting on a small dataset

# %% [markdown]
# > **⚠️ Leakage note (different from David's Prophet case):**
# > David had to lag his price/production features by 24h because they would otherwise leak the future. For a *pure weather → weather* LSTM, the sliding-window construction in Phase 2 handles this structurally: `X` only ever contains the **past** window, and `y` only the **future** window. So no manual lagging is needed — **as long as every feature you include is something genuinely available at prediction time.** If you later add a feature that "knows the future," you'd need to lag it like David did.

# %% [markdown]
# ## Phase 2 — Data Preparation (Time Series sequences)

# %%
# ─── Configuration (all TUNE-able) ──────────────────────────────────
TARGET           = 'el_price_dol_MWh_OTA2201'   # TUNE: the weather variable to predict
INPUT_LENGTH     = 168             # TUNE: 7 days of hourly history as input. CHANGE LATER TO 336 TO LOOK AT 2 WEEKS
OUTPUT_LENGTH    = 24              # fixed: predict 24 hours ahead. CHANGE LATER TO 168 TO PREDICT 1 WEEK
HORIZON          = 1               # gap between last input and first prediction
STRIDE           = 1               # TUNE: step between consecutive sequences
FOLD_LENGTH      = 24 * 365        # TUNE: 1 year per fold
FOLD_STRIDE      = 24 * 182        # TUNE: ~6 month stride between folds
TRAIN_TEST_RATIO = 0.8

# Index of the target column WITHIN the feature array (needed for the baseline)
TARGET_COLUMN_IDX = df.columns.get_loc(TARGET)

# %%
# ─── Step 1: Create folds (sliding window over full dataset) ─────────
def get_folds(df: pd.DataFrame, fold_length: int, fold_stride: int) -> List[pd.DataFrame]:
    folds = []
    for idx in range(0, len(df), fold_stride):
        if (idx + fold_length) > len(df):
            break
        folds.append(df.iloc[idx:idx + fold_length, :])
    return folds

# %%
# ─── Step 2: Chronological train/test split per fold (with horizon gap) ──
def train_test_split(fold, train_test_ratio, input_length, horizon):
    train_end  = round(train_test_ratio * len(fold))
    test_start = train_end - input_length + horizon   # leaves lookback + gap
    return fold.iloc[:train_end], fold.iloc[test_start:]

# %%
# ─── Step 3: Extract (Xi, yi) sequence pairs ─────────────────────────
# NOTE: simplified from the bootcamp version to use positional indexing,
# so it works with a DatetimeIndex (the bootcamp version assumed a RangeIndex).
def get_X_y(fold, horizon, input_length, output_length, stride, shuffle=True):
    X, y = [], []
    n = len(fold)
    last_start = n - input_length - horizon - output_length + 2
    for start in range(0, last_start, stride):
        Xi = fold.iloc[start : start + input_length]
        y_start = start + input_length + horizon - 1
        yi = fold.iloc[y_start : y_start + output_length][TARGET]
        X.append(Xi.values)
        y.append(yi.values)
    X, y = np.array(X), np.array(y)
    if shuffle:
        idx = np.random.permutation(len(X))
        X, y = X[idx], y[idx]
    return X, y

# %%
# ─── Build folds and a first (Xi, yi) set to sanity-check shapes ─────
folds = get_folds(df, FOLD_LENGTH, FOLD_STRIDE)

fold_train, fold_test = train_test_split(folds[0], TRAIN_TEST_RATIO, INPUT_LENGTH, HORIZON)
X_train, y_train = get_X_y(fold_train, HORIZON, INPUT_LENGTH, OUTPUT_LENGTH, STRIDE)
X_test,  y_test  = get_X_y(fold_test,  HORIZON, INPUT_LENGTH, OUTPUT_LENGTH, STRIDE, shuffle=False)

print(f"Number of folds: {len(folds)}")
print(f"X_train: {X_train.shape}")   # (n_sequences, INPUT_LENGTH, N_FEATURES)
print(f"y_train: {y_train.shape}")   # (n_sequences, OUTPUT_LENGTH)
# Out:
# Number of folds: 11
# X_train: (6817, 168, 85)
# y_train: (6817, 24)

# %% [markdown]
# ## Phase 3 — Architecture

# %%
def init_model(X_train):
    # Normalization baked into the model, fitted on TRAIN data only (no leakage)
    normalizer = Normalization()
    normalizer.adapt(X_train)

    model = models.Sequential()
    model.add(Input(shape=X_train[0].shape))     # (INPUT_LENGTH, N_FEATURES)
    model.add(normalizer)

    # Recurrent layer
    model.add(layers.LSTM(units=64,               # MAKE EDITS HERE IF NEEDED: 32 OR 64
                          activation='tanh',      #!!!!! ASK ANDREII
                          return_sequences=False,
                          dropout=0.2))           # TUNE: lighter than bootcamp 0.5

    # Dense hidden layer
    model.add(layers.Dense(32, activation='relu'))  # TUNE
    model.add(layers.Dropout(0.2))                  # TUNE

    # Output — one neuron per future timestep (24)
    model.add(layers.Dense(OUTPUT_LENGTH, activation='linear'))

    # Exponential decay learning rate
    lr_schedule = ExponentialDecay(initial_learning_rate=0.01,   # TUNE
                                   decay_steps=1000,
                                   decay_rate=0.5)
    model.compile(loss='mse',                                   # MAKE EDITS: change to MAE or Huber
                  optimizer=optimizers.Adam(learning_rate=lr_schedule),
                  metrics=['mae', 'root_mean_squared_error'])              # MAKE EDITS: change metrics reported if needed
    return model

# %%
model = init_model(X_train)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 168, 85)        │           171 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        38,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24)             │           792 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,443 (161.89 KB)
#  Trainable params: 41,272 (161.22 KB)
#  Non-trainable params: 171 (688.00 B)

# %% [markdown]
# ## Phase 4 — Fit

# %%
def fit_model(model, X_train, y_train, verbose=1):
    es = EarlyStopping(monitor='val_loss',
                       patience=3,            # TUNE
                       mode='min',
                       restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_split = 0.3,
        shuffle          = False,   # MANDATORY for time series
        batch_size       = 32,      # TUNE
        epochs           = 50,     # early stopping decides the real number
        callbacks        = [es],
        verbose          = verbose,
    )
    return model, history

# %%
model, history = fit_model(model, X_train, y_train)
# Out:
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - loss: 2438.5144 - mae: 32.3868 - root_mean_squared_error: 49.3813 - val_loss: 2070.8235 - val_mae: 29.2878 - val_root_mean_squared_error: 45.5063
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 2376.1831 - mae: 31.9335 - root_mean_squared_error: 48.7461 - val_loss: 2052.8062 - val_mae: 29.3576 - val_root_mean_squared_error: 45.3079
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 2375.6970 - mae: 31.9395 - root_mean_squared_error: 48.7411 - val_loss: 2036.1753 - val_mae: 29.2027 - val_root_mean_squared_error: 45.1240
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 2368.8303 - mae: 31.8847 - root_mean_squared_error: 48.6706 - val_loss: 2025.7900 - val_mae: 29.3379 - val_root_mean_squared_error: 45.0088
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 2342.7239 - mae: 31.8884 - root_mean_squared_error: 48.4017 - val_loss: 1988.2009 - val_mae: 28.7490 - val_root_mean_squared_error: 44.5892
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 2341.0535 - mae: 31.7132 - root_mean_squared_error: 48.3844 - val_loss: 1973.7950 - val_mae: 28.5074 - val_root_mean_squared_error: 44.4274
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 2312.5632 - mae: 31.5550 - root_mean_squared_error: 48.0891 - val_loss: 1971.7385 - val_mae: 28.1908 - val_root_mean_squared_error: 44.4043
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 2312.0542 - mae: 31.5048 - root_mean_squared_error: 48.0838 - val_loss: 1955.9929 - val_mae: 28.1929 - val_root_mean_squared_error: 44.2266
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 2284.6912 - mae: 31.2692 - root_mean_squared_error: 47.7984 - val_loss: 1934.1921 - val_mae: 28.0919 - val_root_mean_squared_error: 43.9795
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 2293.8259 - mae: 31.4217 - root_mean_squared_error: 47.8939 - val_loss: 1926.3065 - val_mae: 27.9197 - val_root_mean_squared_error: 43.8897
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 2263.5183 - mae: 31.1518 - root_mean_squared_error: 47.5764 - val_loss: 1917.4316 - val_mae: 27.8542 - val_root_mean_squared_error: 43.7885
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 2259.5933 - mae: 31.1475 - root_mean_squared_error: 47.5352 - val_loss: 1907.8008 - val_mae: 27.8399 - val_root_mean_squared_error: 43.6784
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 2259.6147 - mae: 31.1070 - root_mean_squared_error: 47.5354 - val_loss: 1898.7094 - val_mae: 27.7294 - val_root_mean_squared_error: 43.5742
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 2252.2451 - mae: 31.1122 - root_mean_squared_error: 47.4578 - val_loss: 1885.7568 - val_mae: 27.7048 - val_root_mean_squared_error: 43.4253
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 2222.0549 - mae: 30.8206 - root_mean_squared_error: 47.1387 - val_loss: 1882.7941 - val_mae: 27.7488 - val_root_mean_squared_error: 43.3912
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 2241.8425 - mae: 30.9828 - root_mean_squared_error: 47.3481 - val_loss: 1879.4858 - val_mae: 27.6431 - val_root_mean_squared_error: 43.3530
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 2220.7361 - mae: 30.8229 - root_mean_squared_error: 47.1247 - val_loss: 1867.9706 - val_mae: 27.6498 - val_root_mean_squared_error: 43.2200
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 2198.3958 - mae: 30.6922 - root_mean_squared_error: 46.8871 - val_loss: 1864.8113 - val_mae: 27.4853 - val_root_mean_squared_error: 43.1835
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 2213.8396 - mae: 30.6812 - root_mean_squared_error: 47.0515 - val_loss: 1858.6221 - val_mae: 27.5266 - val_root_mean_squared_error: 43.1117
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 2207.1150 - mae: 30.7666 - root_mean_squared_error: 46.9799 - val_loss: 1852.7527 - val_mae: 27.4982 - val_root_mean_squared_error: 43.0436
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2213.3413 - mae: 30.7959 - root_mean_squared_error: 47.0462 - val_loss: 1846.1827 - val_mae: 27.3970 - val_root_mean_squared_error: 42.9672
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 2196.3296 - mae: 30.6856 - root_mean_squared_error: 46.8650 - val_loss: 1841.4678 - val_mae: 27.3302 - val_root_mean_squared_error: 42.9123
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2167.1282 - mae: 30.4499 - root_mean_squared_error: 46.5524 - val_loss: 1839.7762 - val_mae: 27.2872 - val_root_mean_squared_error: 42.8926
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 2195.1829 - mae: 30.6516 - root_mean_squared_error: 46.8528 - val_loss: 1836.7700 - val_mae: 27.1645 - val_root_mean_squared_error: 42.8576
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 2161.8303 - mae: 30.4837 - root_mean_squared_error: 46.4955 - val_loss: 1831.0774 - val_mae: 27.1711 - val_root_mean_squared_error: 42.7911
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 2173.0234 - mae: 30.5152 - root_mean_squared_error: 46.6157 - val_loss: 1825.8326 - val_mae: 27.0650 - val_root_mean_squared_error: 42.7298
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2183.6082 - mae: 30.5843 - root_mean_squared_error: 46.7291 - val_loss: 1821.2408 - val_mae: 27.1346 - val_root_mean_squared_error: 42.6760
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 2156.9631 - mae: 30.3399 - root_mean_squared_error: 46.4431 - val_loss: 1818.5548 - val_mae: 27.1246 - val_root_mean_squared_error: 42.6445
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2165.5808 - mae: 30.4877 - root_mean_squared_error: 46.5358 - val_loss: 1814.6713 - val_mae: 27.0774 - val_root_mean_squared_error: 42.5990
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2155.7688 - mae: 30.2956 - root_mean_squared_error: 46.4303 - val_loss: 1812.6344 - val_mae: 27.0831 - val_root_mean_squared_error: 42.5750
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 2170.7043 - mae: 30.5465 - root_mean_squared_error: 46.5908 - val_loss: 1811.8079 - val_mae: 26.9841 - val_root_mean_squared_error: 42.5653
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 2171.5056 - mae: 30.3508 - root_mean_squared_error: 46.5994 - val_loss: 1808.8947 - val_mae: 27.0208 - val_root_mean_squared_error: 42.5311
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2153.6709 - mae: 30.3819 - root_mean_squared_error: 46.4077 - val_loss: 1807.7798 - val_mae: 26.9562 - val_root_mean_squared_error: 42.5180
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - loss: 2172.9028 - mae: 30.4227 - root_mean_squared_error: 46.6144 - val_loss: 1804.7386 - val_mae: 27.0210 - val_root_mean_squared_error: 42.4822
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 2150.8416 - mae: 30.2994 - root_mean_squared_error: 46.3772 - val_loss: 1803.6594 - val_mae: 26.9242 - val_root_mean_squared_error: 42.4695
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 2158.4756 - mae: 30.3653 - root_mean_squared_error: 46.4594 - val_loss: 1801.3047 - val_mae: 26.9842 - val_root_mean_squared_error: 42.4418
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - loss: 2137.3801 - mae: 30.1983 - root_mean_squared_error: 46.2318 - val_loss: 1800.2081 - val_mae: 26.9568 - val_root_mean_squared_error: 42.4289
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - loss: 2149.7771 - mae: 30.2788 - root_mean_squared_error: 46.3657 - val_loss: 1799.4568 - val_mae: 26.9278 - val_root_mean_squared_error: 42.4200
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 2145.0586 - mae: 30.2681 - root_mean_squared_error: 46.3148 - val_loss: 1798.9005 - val_mae: 26.9071 - val_root_mean_squared_error: 42.4134
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 2139.1072 - mae: 30.1815 - root_mean_squared_error: 46.2505 - val_loss: 1797.1859 - val_mae: 26.9068 - val_root_mean_squared_error: 42.3932
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 2156.5759 - mae: 30.2544 - root_mean_squared_error: 46.4389 - val_loss: 1796.3934 - val_mae: 26.9087 - val_root_mean_squared_error: 42.3839
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 2153.0269 - mae: 30.2797 - root_mean_squared_error: 46.4007 - val_loss: 1795.7158 - val_mae: 26.8819 - val_root_mean_squared_error: 42.3759
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 2157.7324 - mae: 30.2960 - root_mean_squared_error: 46.4514 - val_loss: 1794.6067 - val_mae: 26.9080 - val_root_mean_squared_error: 42.3628
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - loss: 2154.4832 - mae: 30.1559 - root_mean_squared_error: 46.4164 - val_loss: 1793.9371 - val_mae: 26.9240 - val_root_mean_squared_error: 42.3549
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 2143.8384 - mae: 30.2520 - root_mean_squared_error: 46.3016 - val_loss: 1793.8365 - val_mae: 26.8890 - val_root_mean_squared_error: 42.3537
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 2152.9260 - mae: 30.2581 - root_mean_squared_error: 46.3996 - val_loss: 1793.2058 - val_mae: 26.9002 - val_root_mean_squared_error: 42.3463
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 2153.3369 - mae: 30.3729 - root_mean_squared_error: 46.4041 - val_loss: 1792.6195 - val_mae: 26.8785 - val_root_mean_squared_error: 42.3393
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 2140.9314 - mae: 30.1726 - root_mean_squared_error: 46.2702 - val_loss: 1792.3748 - val_mae: 26.8773 - val_root_mean_squared_error: 42.3364
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 2134.6560 - mae: 30.2954 - root_mean_squared_error: 46.2023 - val_loss: 1791.7648 - val_mae: 26.8812 - val_root_mean_squared_error: 42.3292
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 2158.3191 - mae: 30.3450 - root_mean_squared_error: 46.4577 - val_loss: 1791.3414 - val_mae: 26.8818 - val_root_mean_squared_error: 42.3242

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'],     label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epoch'); plt.ylabel('MSE'); plt.legend()
plt.title('Learning curve'); plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Phase 5 — Evaluate & Cross-Validate

# %% [markdown]
# ### Single-fold evaluation + baseline

# %%
# LSTM performance on this fold's test set
res = model.evaluate(X_test, y_test, verbose=0)
mae_lstm = res[1]

# Baseline: repeat the last seen target value across all 24 future hours
def last_seen_value_baseline(X_test, y_test):
    last_seen = X_test[:, -1, TARGET_COLUMN_IDX].reshape(-1, 1)
    repeated  = np.repeat(last_seen, axis=1, repeats=OUTPUT_LENGTH)
    return np.mean(np.abs(y_test - repeated))

mae_baseline = last_seen_value_baseline(X_test, y_test)

print(f"Baseline MAE: {mae_baseline:.3f}")
print(f"LSTM MAE:     {mae_lstm:.3f}")
print(f"Improvement:  {(1 - mae_lstm/mae_baseline)*100:.1f}%")

# %% [markdown]
# ### Full cross-validation across all folds

# %%
list_mae_baseline, list_mae_lstm = [], []

for fold_id, fold in enumerate(folds):
    fold_train, fold_test = train_test_split(fold, TRAIN_TEST_RATIO, INPUT_LENGTH, HORIZON)
    X_train, y_train = get_X_y(fold_train, HORIZON, INPUT_LENGTH, OUTPUT_LENGTH, STRIDE)
    X_test,  y_test  = get_X_y(fold_test,  HORIZON, INPUT_LENGTH, OUTPUT_LENGTH, STRIDE, shuffle=False)

    # Baseline
    mae_baseline = last_seen_value_baseline(X_test, y_test)
    list_mae_baseline.append(mae_baseline)

    # LSTM (fresh model per fold)
    model    = init_model(X_train)
    model, _ = fit_model(model, X_train, y_train, verbose=0)
    res      = model.evaluate(X_test, y_test, verbose=0)
    list_mae_lstm.append(res[1])

    print(f"Fold {fold_id} — Baseline: {mae_baseline:.3f} | LSTM: {res[1]:.3f}")

print(f"\nCV Baseline MAE: {np.mean(list_mae_baseline):.3f}")
print(f"CV LSTM MAE:     {np.mean(list_mae_lstm):.3f}")
print(f"Avg improvement: {(1 - np.mean(list_mae_lstm)/np.mean(list_mae_baseline))*100:.1f}%")

# %% [markdown]
# ## Phase 6 — Predict the Next 24 Hours

# %%
# Build a single input window from the most recent data
latest_window = df.iloc[-INPUT_LENGTH:].values            # (INPUT_LENGTH, N_FEATURES)
latest_window = latest_window[np.newaxis, ...]            # (1, INPUT_LENGTH, N_FEATURES)

# Predict the next 24 hours
forecast_24h = model.predict(latest_window)[0]            # shape (24,)

# Attach future timestamps for readability
last_ts = df.index[-1]
future_index = pd.date_range(last_ts + pd.Timedelta(hours=1), periods=OUTPUT_LENGTH, freq='h')
forecast_series = pd.Series(forecast_24h, index=future_index, name=f'{TARGET}_forecast')

print(forecast_series)

# Quick visual
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
df[TARGET].iloc[-INPUT_LENGTH:].plot(label='history')
forecast_series.plot(label='24h forecast', linestyle='--')
plt.legend(); plt.title(f'{TARGET}: last week + 24h forecast'); plt.grid(alpha=0.3)
plt.show()
